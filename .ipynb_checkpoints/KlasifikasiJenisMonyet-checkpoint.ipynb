# %%
#Importing Libraries
import os
import numpy as np
import pandas as pd

import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import metrics
from tensorflow.keras.preprocessing.image import load_img, ImageDataGenerator
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Flatten
from sklearn.metrics import classification_report, accuracy_score, recall_score, precision_score, f1_score

# %%
#Fetch Images count from Fodlers

# %%
count = 0 
dirs = os.listdir('Images/')
for dir in dirs:
    files = list(os.listdir('Images/'+dir))
    print( dir +' Folder has '+ str(len(files)) + ' Images')
    count = count + len(files)
print( 'Images Folder has '+ str(count) + ' Images')
# Out:
# Bald Uakari Folder has 110 Images
# Black Headed Night Monkey Folder has 106 Images
# Common Squirrel Monkey Folder has 114 Images
# Japanese Macaque Folder has 122 Images
# Mantled Howler Folder has 105 Images
# Nilgiri Langur Folder has 106 Images
# Patas Monkey Folder has 111 Images
# Pygmy Marmoset Folder has 105 Images
# Silvery Marmoset Folder has 106 Images
# White Headed Capuchin Folder has 113 Images
# Images Folder has 1098 Images

# %%
#Load Images into Arrays as Dataset

# %%
base_dir = 'Images/'
img_size = 180
batch = 32

# %%
train_ds = tf.keras.utils.image_dataset_from_directory( base_dir,
                                                       seed = 123,
                                                       validation_split=0.2,
                                                       subset = 'training',
                                                       batch_size=batch,
                                                       image_size=(img_size,img_size))

val_ds = tf.keras.utils.image_dataset_from_directory( base_dir,
                                                       seed = 123,
                                                       validation_split=0.2,
                                                       subset = 'validation',
                                                       batch_size=batch,
                                                       image_size=(img_size,img_size))
# Out:
# Found 1097 files belonging to 10 classes.
# Using 878 files for training.
# Found 1097 files belonging to 10 classes.
# Using 219 files for validation.

# %%
monkey_names = train_ds.class_names
monkey_names
# Out:
# ['Bald Uakari',
#  'Black Headed Night Monkey',
#  'Common Squirrel Monkey',
#  'Japanese Macaque',
#  'Mantled Howler',
#  'Nilgiri Langur',
#  'Patas Monkey',
#  'Pygmy Marmoset',
#  'Silvery Marmoset',
#  'White Headed Capuchin']

# %%
import matplotlib.pyplot as plt

# %%
i = 0
plt.figure(figsize=(9,9))

for images, labels in train_ds.take(1):
    for i in range(25):
        plt.subplot(5,5, i+1)
        plt.imshow(images[i].numpy().astype('uint8'))
        plt.title(monkey_names[labels[i]])
        plt.axis('off')

# %%
AUTOTUNE = tf.data.AUTOTUNE

# %%
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size = AUTOTUNE)

# %%
val_ds = val_ds.cache().prefetch(buffer_size = AUTOTUNE)

# %%
#Data Augmentation

# %%
data_augmentation = Sequential([
    layers.RandomFlip("horizontal", input_shape = (img_size,img_size,3)),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1)
])

# %%
i = 0
plt.figure(figsize=(10,10))

for images, labels in train_ds.take(1):
    for i in range(9):
        images = data_augmentation(images)
        plt.subplot(3,3, i+1)
        plt.imshow(images[0].numpy().astype('uint8'))
        plt.axis('off')

# %%
#Model Creation

# %%
model = Sequential([
    data_augmentation,
    layers.Rescaling(1./255),
    Conv2D(16, 3, padding='same', activation='relu'),
    MaxPooling2D(),
    Conv2D(32, 3, padding='same', activation='relu'),
    MaxPooling2D(),
    Conv2D(64, 3, padding='same', activation='relu'),
    MaxPooling2D(),
    Dropout(0.2),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(10)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ sequential_4 (Sequential)            │ (None, 180, 180, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ rescaling_2 (Rescaling)              │ (None, 180, 180, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_6 (Conv2D)                    │ (None, 180, 180, 16)        │             448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_6 (MaxPooling2D)       │ (None, 90, 90, 16)          │               0 │
# ...

# %%
history = model.fit(train_ds, epochs=50, validation_data=val_ds)
# Out:
# Epoch 1/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 11s 227ms/step - accuracy: 0.1351 - loss: 2.3718 - val_accuracy: 0.3333 - val_loss: 1.9509
# Epoch 2/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 190ms/step - accuracy: 0.3469 - loss: 1.8312 - val_accuracy: 0.4521 - val_loss: 1.5384
# Epoch 3/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 193ms/step - accuracy: 0.4607 - loss: 1.5027 - val_accuracy: 0.4886 - val_loss: 1.4076
# Epoch 4/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 193ms/step - accuracy: 0.5394 - loss: 1.2775 - val_accuracy: 0.5525 - val_loss: 1.2678
# Epoch 5/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 191ms/step - accuracy: 0.6164 - loss: 1.1735 - val_accuracy: 0.5434 - val_loss: 1.3810
# Epoch 6/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 188ms/step - accuracy: 0.5911 - loss: 1.1840 - val_accuracy: 0.5388 - val_loss: 1.3765
# Epoch 7/50
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 188ms/step - accuracy: 0.6096 - loss: 1.0214 - val_accuracy: 0.5525 - val_loss: 1.3639
# Epoch 8/50
# ...

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(50)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
def classify_images(image_path): 
    input_image = tf.keras.utils.load_img(image_path, target_size=(180, 180))
    input_image_array = tf.keras.utils.img_to_array(input_image)
    input_image_exp_dim = tf.expand_dims(input_image_array, 0)

    predictions = model.predict(input_image_exp_dim)
    predicted_label = np.argmax(predictions)
    result = tf.nn.softmax(predictions[0])

    y_pred = model.predict(val_ds)
    y_pred = np.argmax(y_pred, axis=1)
    
    y_true = np.concatenate([y for x, y in val_ds], axis=0)

    
    class_names = 'Bald Uakari', 'Black Headed Night Monkey', 'Common Squirrel Monkey','Japanese Macaque','Mantled Howler','Nilgiri Langur', 'Patas Monkey', 'Pygmy Marmoset','Silvery Marmoset','White Headed Capuchin'
    cr = classification_report(y_true, y_pred, output_dict=True)

    graph = pd.DataFrame.from_dict(cr)
    outcome = 'Gambar diatas termasuk dalam Jenis ' + monkey_names[predicted_label] + ' dengan skor Confidence ' + str(np.max(result) * 100)
    
    return outcome, graph

# %%
classify_images("Samples/4.jpg")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[496], line 1
# ----> 1 classify_images("Samples/4.jpg")
#
# Cell In[494], line 15, in classify_images(image_path)
#      11 y_pred = np.argmax(y_pred, axis=1)
#      13 y_true = np.concatenate([y for x, y in val_ds], axis=0)
# ---> 15 print(y_true[pred_filter])
#      16 print(y_pred[pred_filter])
#      17 print(acc)
#
# NameError: name 'pred_filter' is not defined

# %%
model.save('Model_Monyet.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
